# %% [markdown]
# # [Deep Learning](https://github.com/M-Sc-AUT/M.Sc-Computer-Architecture/tree/main/Deep%20Learning) - Spring 2024
# #### [Reza Adinepour](https://github.com/rezaAdinepour)
# #### Stu.ID: 402131055

# %% [markdown]
# ## Question 5 - Part (A):
#
# I use CIFAR dataset for this question. You can download here: [github.com/YoongiKim/CIFAR-10-images.git](https://github.com/YoongiKim/CIFAR-10-images.git)

# %% [markdown]
# ### connect to the google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/DeepLearning-Spring2024/HWs/HW02/'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DeepLearning-Spring2024/HWs/HW02

# %% [markdown]
# ### import libraries

# %%
import torch
from torch import nn, optim
import cv2
import matplotlib.pyplot as plt
import random
import os
import numpy as np
from skimage.util import img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr

# %% [markdown]
# ### check GPU availability

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ### function for load images from personal dir

# %%
def read_img(dir, format):
    images = []
    for img in os.listdir(dir):
        if (img.endswith("." + format)):
            images.append(cv2.imread(os.path.join(dir, img)))
    return len(images), images

# %% [markdown]
# ### load images

# %%
dir = "Dataset-Q5/"
_, images = read_img(dir, "jpg")
print("total images: ", len(images))
# Out:
# total images:  10

# %% [markdown]
# ### plot full resolution images

# %%
plt.figure(figsize=(8, 6))
for i, img in enumerate(images):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title(f"Image {i + 1}")
    plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-9b74d0c312a4>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 5, i + 1)

# %% [markdown]
# ### half resulution of images

# %%
half_res_img = []
for img in images:
    half_res_img.append(cv2.resize(img, (img.shape[0] // 2, img.shape[1] // 2)))

# %% [markdown]
# ### plot half resolution of images

# %%
plt.figure(figsize=(8, 6))
for i, img in enumerate(half_res_img):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title(f"Image {i + 1}")
    plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-64b90bebe7ef>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 5, i + 1)

# %% [markdown]
# ### extract features

# %%
dataset = []

for img, half_res_img in zip(images, half_res_img):

    # conver img and half_res_img from BGR to RGB
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    half_res_img = cv2.cvtColor(half_res_img, cv2.COLOR_BGR2RGB)
    # shape of half_res_img is: (16, 16, 3)

    # pad the lower resolution image with zeros
    half_res_img = cv2.copyMakeBorder(half_res_img, 1, 1, 1, 1, cv2.BORDER_CONSTANT, value=[0, 0, 0])
    # shape of half_res_img is: (18, 18, 3)

    img_dataset = []

    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            # Map the pixel to the lower resolution image
            i_half = i // 2
            j_half = j // 2

            # find the eight neighbors
            neighbors = []
            # if initial pixel is (i, j) in this loop find the neighbors
            # (i-1, j-1), (i-1, j), (i-1, j+1), and ...
            for di in [-1, 0, 1]:
                for dj in [-1, 0, 1]:
                    # append each color channel separately
                    neighbors.extend(half_res_img[i_half + di + 1, j_half + dj + 1].tolist())

            # add the neighbors and the original pixel to the image dataset
            img_dataset.append((neighbors, img[i, j].tolist()))
    dataset.append(img_dataset)

# convert dataset to a PyTorch tensor
dataset = [[torch.tensor(data[0], dtype=torch.float, device=device),
             torch.tensor(data[1], dtype=torch.float, device=device)]
               for img_data in dataset for data in img_data]

# %% [markdown]
# ### stack dataset into the features and labels

# %%
features = torch.stack([img_data[0] for img_data in dataset])
labels = torch.stack([img_data[1] for img_data in dataset])

print(f"Size of features tensor: {features.size()}")
print(f"Size of labels tensor: {labels.size()}")
# Out:
# Size of features tensor: torch.Size([10240, 27])
# Size of labels tensor: torch.Size([10240, 3])

# %% [markdown]
# ### split dataset into the train, test and validation sets
# * training set: 7 image
# * testing set: 2 image
# * validation set: 1 image

# %%
train_dataset = dataset[:7*32*32]
test_dataset = dataset[7*32*32:9*32*32]
val_dataset = dataset[9*32*32:]

random.shuffle(train_dataset) # shuffle the training dataset

# %% [markdown]
# ### stack features and labels separately for each dataset

# %%
train_features = torch.stack([data[0] for data in train_dataset])
train_labels = torch.stack([data[1] for data in train_dataset])
test_features = torch.stack([data[0] for data in test_dataset])
test_labels = torch.stack([data[1] for data in test_dataset])
val_features = torch.stack([data[0] for data in val_dataset])
val_labels = torch.stack([data[1] for data in val_dataset])

print(f"Size of training features tensor: {train_features.size()}")
print(f"Size of training labels tensor: {train_labels.size()}")
print()
print(f"Size of testing features tensor: {test_features.size()}")
print(f"Size of testing labels tensor: {test_labels.size()}")
print()
print(f"Size of validation features tensor: {val_features.size()}")
print(f"Size of validation labels tensor: {val_labels.size()}")
# Out:
# Size of training features tensor: torch.Size([7168, 27])
# Size of training labels tensor: torch.Size([7168, 3])
#
# Size of testing features tensor: torch.Size([2048, 27])
# Size of testing labels tensor: torch.Size([2048, 3])
#
# Size of validation features tensor: torch.Size([1024, 27])
# Size of validation labels tensor: torch.Size([1024, 3])

# %% [markdown]
# ### define network
# * input lauer: 27 neurons
# * hidden layer1: 64 neurons
# * activation function of layer 1: ReLU
# * hidden layer2: 128 neurons
# * activation function of layer 1: ReLU
# * output lauer: 3 neurons

# %%
class multi_layer_perceptron(nn.Module):
    def __init__(self):
        super(multi_layer_perceptron, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(27, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 3)
        )

    def forward(self, x):
        return self.layers(x)

# %% [markdown]
# ### set network parameters

# %%
model = multi_layer_perceptron().to(device)

criterion = nn.MSELoss() # use mean squared error loss
optimizer = optim.Adam(model.parameters(), lr=0.001) # use adam optimizer

train_loss_values = []
train_accuracy_values = []
test_loss_values = []
test_accuracy_values = []
val_loss_values = []
val_accuracy_values = []

EPOCH = 50

# %% [markdown]
# ### function to calculate loss and accuracy

# %%
def calculate_loss_accuracy(dataset):
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    with torch.no_grad():
        for i, data in enumerate(dataset, 0):
            inputs, labels = data[0].to(device), data[1].to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            total_predictions += labels.size(0)
            correct_predictions += ((outputs - labels).abs() / labels.abs() < 0.1).sum().item()

            running_loss += loss.item()
    avg_loss = running_loss / len(dataset)
    accuracy = correct_predictions / total_predictions
    return avg_loss, accuracy

# %% [markdown]
# ### train phase

# %%
for epoch in range(EPOCH):
    model.train()
    running_loss = 0
    correct_predictions = 0
    total_predictions = 0
    for i, data in enumerate(train_dataset, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_predictions += labels.size(0)
        correct_predictions += ((outputs - labels).abs() / labels.abs() < 0.1).sum().item()

        running_loss += loss.item()
    avg_loss = running_loss / len(train_dataset)
    accuracy = correct_predictions / total_predictions
    train_loss_values.append(avg_loss)
    train_accuracy_values.append(accuracy)

    model.eval()
    test_loss, test_accuracy = calculate_loss_accuracy(test_dataset)
    test_loss_values.append(test_loss)
    test_accuracy_values.append(test_accuracy)

    val_loss, val_accuracy = calculate_loss_accuracy(val_dataset)
    val_loss_values.append(val_loss)
    val_accuracy_values.append(val_accuracy)

    print ('Epoch [{}/{}] Train Loss: {:.4f} | Train Accuracy: {:.2f} | Test Loss: {:.4f} | Test Accuracy: {:.2f} | Validation Loss: {:.4f} | Validation Accuracy: {:.2f}  '.format(epoch+1,
            EPOCH, avg_loss, accuracy, test_loss, test_accuracy, val_loss, val_accuracy))
# Out:
# Epoch [1/50] Train Loss: 499.4218 | Train Accuracy: 0.51 | Test Loss: 435.8135 | Test Accuracy: 0.43 | Validation Loss: 558.7234 | Validation Accuracy: 0.45
# Epoch [2/50] Train Loss: 353.8758 | Train Accuracy: 0.56 | Test Loss: 342.2832 | Test Accuracy: 0.52 | Validation Loss: 408.9158 | Validation Accuracy: 0.60
# Epoch [3/50] Train Loss: 334.1081 | Train Accuracy: 0.58 | Test Loss: 327.4165 | Test Accuracy: 0.53 | Validation Loss: 386.9798 | Validation Accuracy: 0.63
# Epoch [4/50] Train Loss: 322.8110 | Train Accuracy: 0.59 | Test Loss: 322.9423 | Test Accuracy: 0.53 | Validation Loss: 374.4883 | Validation Accuracy: 0.63
# Epoch [5/50] Train Loss: 315.4593 | Train Accuracy: 0.60 | Test Loss: 294.3932 | Test Accuracy: 0.57 | Validation Loss: 332.1413 | Validation Accuracy: 0.67
# Epoch [6/50] Train Loss: 309.0110 | Train Accuracy: 0.60 | Test Loss: 299.3613 | Test Accuracy: 0.57 | Validation Loss: 334.9467 | Validation Accuracy: 0.67
# Epoch [7/50] Train Loss: 304.6461 | Train Accuracy: 0.60 | Test Loss: 295.1069 | Test Accuracy: 0.57 | Validation Loss: 328.9909 | Validation Accuracy: 0.68
# Epoch [8/50] Train Loss: 301.3226 | Train Accuracy: 0.61 | Test Loss: 287.5608 | Test Accuracy: 0.58 | Validation Loss: 309.2860 | Validation Accuracy: 0.70
# Epoch [9/50] Train Loss: 299.3808 | Train Accuracy: 0.61 | Test Loss: 280.2492 | Test Accuracy: 0.59 | Validation Loss: 302.7391 | Validation Accuracy: 0.70
# Epoch [10/50] Train Loss: 297.5778 | Train Accuracy: 0.61 | Test Loss: 278.2466 | Test Accuracy: 0.59 | Validation Loss: 295.6185 | Validation Accuracy: 0.71
# Epoch [11/50] Train Loss: 296.0371 | Train Accuracy: 0.61 | Test Loss: 275.9982 | Test Accuracy: 0.59 | Validation Loss: 291.9391 | Validation Accuracy: 0.71
# Epoch [12/50] Train Loss: 294.1414 | Train Accuracy: 0.62 | Test Loss: 274.6855 | Test Accuracy: 0.60 | Validation Loss: 296.2102 | Validation Accuracy: 0.71
# Epoch [13/50] Train Loss: 292.2153 | Train Accuracy: 0.62 | Test Loss: 271.4136 | Test Accuracy: 0.60 | Validation Loss: 289.9170 | Validation Accuracy: 0.71
# Epoch [14/50] Train Loss: 291.0199 | Train Accuracy: 0.62 | Test Loss: 269.8199 | Test Accuracy: 0.60 | Validation Loss: 281.7972 | Validation Accuracy: 0.71
# Epoch [15/50] Train Loss: 289.7372 | Train Accuracy: 0.62 | Test Loss: 267.3731 | Test Accuracy: 0.60 | Validation Loss: 278.0734 | Validation Accuracy: 0.72
# Epoch [16/50] Train Loss: 288.5073 | Train Accuracy: 0.62 | Test Loss: 266.0971 | Test Accuracy: 0.61 | Validation Loss: 277.9954 | Validation Accuracy: 0.72
# Epoch [17/50] Train Loss: 287.8419 | Train Accuracy: 0.62 | Test Loss: 265.1543 | Test Accuracy: 0.61 | Validation Loss: 275.7060 | Validation Accuracy: 0.72
# Epoch [18/50] Train Loss: 287.1040 | Train Accuracy: 0.62 | Test Loss: 263.3659 | Test Accuracy: 0.61 | Validation Loss: 274.2631 | Validation Accuracy: 0.71
# Epoch [19/50] Train Loss: 285.6839 | Train Accuracy: 0.62 | Test Loss: 263.4449 | Test Accuracy: 0.61 | Validation Loss: 269.1377 | Validation Accuracy: 0.72
# Epoch [20/50] Train Loss: 285.0995 | Train Accuracy: 0.62 | Test Loss: 260.1954 | Test Accuracy: 0.61 | Validation Loss: 266.3378 | Validation Accuracy: 0.72
# Epoch [21/50] Train Loss: 284.3277 | Train Accuracy: 0.62 | Test Loss: 257.4260 | Test Accuracy: 0.62 | Validation Loss: 264.0874 | Validation Accuracy: 0.72
# Epoch [22/50] Train Loss: 284.7925 | Train Accuracy: 0.62 | Test Loss: 255.3407 | Test Accuracy: 0.62 | Validation Loss: 261.8226 | Validation Accuracy: 0.73
# Epoch [23/50] Train Loss: 283.7795 | Train Accuracy: 0.62 | Test Loss: 255.9419 | Test Accuracy: 0.62 | Validation Loss: 261.7719 | Validation Accuracy: 0.73
# Epoch [24/50] Train Loss: 282.6671 | Train Accuracy: 0.62 | Test Loss: 255.2701 | Test Accuracy: 0.62 | Validation Loss: 260.4776 | Validation Accuracy: 0.73
# Epoch [25/50] Train Loss: 282.4736 | Train Accuracy: 0.62 | Test Loss: 254.1745 | Test Accuracy: 0.62 | Validation Loss: 261.3449 | Validation Accuracy: 0.72
# Epoch [26/50] Train Loss: 281.9572 | Train Accuracy: 0.63 | Test Loss: 253.3485 | Test Accuracy: 0.62 | Validation Loss: 259.0566 | Validation Accuracy: 0.73
# Epoch [27/50] Train Loss: 281.8378 | Train Accuracy: 0.62 | Test Loss: 253.7927 | Test Accuracy: 0.62 | Validation Loss: 261.5901 | Validation Accuracy: 0.72
# Epoch [28/50] Train Loss: 281.5674 | Train Accuracy: 0.62 | Test Loss: 252.5225 | Test Accuracy: 0.62 | Validation Loss: 259.1137 | Validation Accuracy: 0.73
# Epoch [29/50] Train Loss: 281.2964 | Train Accuracy: 0.62 | Test Loss: 252.8471 | Test Accuracy: 0.62 | Validation Loss: 259.1004 | Validation Accuracy: 0.73
# Epoch [30/50] Train Loss: 281.4248 | Train Accuracy: 0.63 | Test Loss: 252.3404 | Test Accuracy: 0.62 | Validation Loss: 258.8867 | Validation Accuracy: 0.73
# Epoch [31/50] Train Loss: 280.5770 | Train Accuracy: 0.63 | Test Loss: 252.0132 | Test Accuracy: 0.62 | Validation Loss: 259.8091 | Validation Accuracy: 0.73
# Epoch [32/50] Train Loss: 280.2036 | Train Accuracy: 0.63 | Test Loss: 250.5769 | Test Accuracy: 0.63 | Validation Loss: 256.4375 | Validation Accuracy: 0.73
# Epoch [33/50] Train Loss: 280.3289 | Train Accuracy: 0.63 | Test Loss: 251.5135 | Test Accuracy: 0.62 | Validation Loss: 259.4102 | Validation Accuracy: 0.73
# Epoch [34/50] Train Loss: 279.7093 | Train Accuracy: 0.63 | Test Loss: 250.5758 | Test Accuracy: 0.62 | Validation Loss: 256.3278 | Validation Accuracy: 0.73
# Epoch [35/50] Train Loss: 279.4858 | Train Accuracy: 0.63 | Test Loss: 249.4648 | Test Accuracy: 0.63 | Validation Loss: 255.5224 | Validation Accuracy: 0.73
# Epoch [36/50] Train Loss: 279.7015 | Train Accuracy: 0.63 | Test Loss: 252.3275 | Test Accuracy: 0.62 | Validation Loss: 256.0505 | Validation Accuracy: 0.73
# Epoch [37/50] Train Loss: 279.0146 | Train Accuracy: 0.63 | Test Loss: 251.5745 | Test Accuracy: 0.62 | Validation Loss: 255.1465 | Validation Accuracy: 0.73
# Epoch [38/50] Train Loss: 278.9984 | Train Accuracy: 0.63 | Test Loss: 252.2613 | Test Accuracy: 0.62 | Validation Loss: 254.9448 | Validation Accuracy: 0.73
# Epoch [39/50] Train Loss: 278.8091 | Train Accuracy: 0.63 | Test Loss: 252.3285 | Test Accuracy: 0.62 | Validation Loss: 255.5381 | Validation Accuracy: 0.73
# Epoch [40/50] Train Loss: 277.8092 | Train Accuracy: 0.63 | Test Loss: 251.2706 | Test Accuracy: 0.62 | Validation Loss: 253.1748 | Validation Accuracy: 0.73
# Epoch [41/50] Train Loss: 277.6447 | Train Accuracy: 0.63 | Test Loss: 249.1558 | Test Accuracy: 0.62 | Validation Loss: 251.4180 | Validation Accuracy: 0.73
# Epoch [42/50] Train Loss: 277.2973 | Train Accuracy: 0.63 | Test Loss: 250.3700 | Test Accuracy: 0.62 | Validation Loss: 251.0364 | Validation Accuracy: 0.73
# Epoch [43/50] Train Loss: 277.3463 | Train Accuracy: 0.63 | Test Loss: 250.3921 | Test Accuracy: 0.62 | Validation Loss: 251.0515 | Validation Accuracy: 0.73
# Epoch [44/50] Train Loss: 277.2433 | Train Accuracy: 0.63 | Test Loss: 249.9838 | Test Accuracy: 0.62 | Validation Loss: 251.1202 | Validation Accuracy: 0.73
# Epoch [45/50] Train Loss: 277.0582 | Train Accuracy: 0.63 | Test Loss: 249.5118 | Test Accuracy: 0.62 | Validation Loss: 249.5758 | Validation Accuracy: 0.74
# Epoch [46/50] Train Loss: 277.2813 | Train Accuracy: 0.63 | Test Loss: 249.5164 | Test Accuracy: 0.62 | Validation Loss: 251.6159 | Validation Accuracy: 0.73
# Epoch [47/50] Train Loss: 276.6839 | Train Accuracy: 0.63 | Test Loss: 248.8125 | Test Accuracy: 0.62 | Validation Loss: 248.7952 | Validation Accuracy: 0.74
# Epoch [48/50] Train Loss: 276.7928 | Train Accuracy: 0.63 | Test Loss: 248.3520 | Test Accuracy: 0.62 | Validation Loss: 248.8914 | Validation Accuracy: 0.73
# Epoch [49/50] Train Loss: 276.4929 | Train Accuracy: 0.63 | Test Loss: 248.9943 | Test Accuracy: 0.62 | Validation Loss: 250.7878 | Validation Accuracy: 0.73
# Epoch [50/50] Train Loss: 276.1686 | Train Accuracy: 0.63 | Test Loss: 248.7143 | Test Accuracy: 0.62 | Validation Loss: 249.7696 | Validation Accuracy: 0.73

# %% [markdown]
# ### plot loss and accuracy for each epoch

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss_values, label='Train')
plt.plot(test_loss_values, label='Test')
plt.plot(val_loss_values, label='Validation')
plt.title('Loss per epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracy_values, label='Train')
plt.plot(test_accuracy_values, label='Test')
plt.plot(val_accuracy_values, label='Validation')
plt.title('Accuracy per epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## part C: reconstruction image

# %%
reconstructed_images = []

for half_res_img in half_res_img:
    half_res_img = cv2.cvtColor(half_res_img, cv2.COLOR_BGR2RGB)

    half_res_img = cv2.copyMakeBorder(half_res_img, 1, 1, 1, 1, cv2.BORDER_CONSTANT, value=[0, 0, 0])

    reconstructed_img = []

    for i in range(1, half_res_img.shape[0] - 1):
        for j in range(1, half_res_img.shape[1] - 1):
            neighbors = []
            for di in [-1, 0, 1]:
                for dj in [-1, 0, 1]:
                    neighbors.extend(half_res_img[i + di, j + dj].tolist())

            neighbors = torch.tensor(neighbors, dtype=torch.float).to(device)
            output = model(neighbors)
            reconstructed_img.append(output.tolist())

    # reshape the reconstructed image to the original image size
    reconstructed_img = np.array(reconstructed_img, dtype=np.uint8).reshape((half_res_img.shape[0] - 2, half_res_img.shape[1] - 2, 3))
    reconstructed_images.append(reconstructed_img)

# %% [markdown]
# ### Calculate SSIM and PSNR

# %%
ssim_values = []
psnr_values = []
for i, img in enumerate(reconstructed_images):
    if (i >= len(images)):
        print(f"Skipping index {i} because it's not in the original images list")
        continue
    img_true = img_as_float(images[i])  # convert the original image to float
    img_test = img_as_float(img)  # convert the reconstructed image to float

    if (img_true.shape != img_test.shape):
        img_test = cv2.resize(img_test, (img_true.shape[1], img_true.shape[0]))

    ssim_values.append(ssim(img_true, img_test, multichannel=True, win_size=3, data_range=1.0))
    psnr_values.append(psnr(img_true, img_test, data_range=1.0))

print(f"Average SSIM: {np.mean(ssim_values)}")
print(f"Average PSNR: {np.mean(psnr_values)}")
# Out:
# Skipping index 10 because it's not in the original images list
# Skipping index 11 because it's not in the original images list
# Skipping index 12 because it's not in the original images list
# Skipping index 13 because it's not in the original images list
# Skipping index 14 because it's not in the original images list
# Skipping index 15 because it's not in the original images list
# Skipping index 16 because it's not in the original images list
# Skipping index 17 because it's not in the original images list
# Average SSIM: 0.11676190683405092
# Average PSNR: 7.096541387860896
# <ipython-input-21-3e75be846017>:13: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim_values.append(ssim(img_true, img_test, multichannel=True, win_size=3, data_range=1.0))

# %% [markdown]
# ### plot results

# %%
plt.figure(figsize=(15, 8))
for i, img in enumerate(reconstructed_images[:10]):
    plt.subplot(2, 5, i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title(f"Reconstructed Image {i + 1}", size=10)
    plt.tight_layout()
plt.show()
# Out:
# <ipython-input-51-3c2f6888fc61>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 5, i + 1)
